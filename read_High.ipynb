# %%
import numpy as np 
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from scipy.optimize import curve_fit
from scipy.stats import t
import PIL
from scipy.special import erf
plt.rcParams['font.family']='serif'
import os 
from matplotlib_scalebar.scalebar import ScaleBar

Npixeles=256
NI=1 #Número de imágenes RAW
NF=1 #Número de imágenes FF
NThr=1 #Número de imágenes contenidas dentro de cada .raw: La primera es la dada por el canal 0 y la segunda es la dada por el canal 1.
nameRAW1="15keV/Nylon_S" #15keV/Nylon_R00_SiC_15keV__d0.75m_a15um_p62um_step-4.2_dith23.25_1.raw
nameRAW2 = "_SiC_15keV__d0.75m_a15um_p62um_step-4.2_dith23.25_" 
nameRAW3 = "_SiC_Poli__d0.75m_a15um_p62um_step-4.2_dith23.25_"
nameRAW4 = "15keV/Nylon_R"
ff_infile= open('Nylon_Air_SiC_2mm_2x_150_75_21kev_FF00_FS50um_Random__d0.75m_a15um_p62um_step-4.2_dith23.25_1.raw','rb')
ff_array = np.fromfile(ff_infile,dtype='float32',count=256*256)
ff_image = PIL.Image.frombuffer("F",[256,256],ff_array,'raw','F',0,1)
ff = np.array(ff_image.getdata())
ff=ff.reshape(256,256)
ff = ff[25:225,25:225]
#num = 7
import os
if not os.path.exists("FS_Measurements_txt_Files"):
    os.makedirs("FS_Measurements_txt_Files")

# %%
from pathlib import Path

# Carpeta principal
main_folder = Path("Poli_Results_Umpa_SiC")

# Lista de focal spots
focal_spots = ["5um", "10um", "20um", "30um", "50um", "100um","75um"]

# Crear carpeta principal
main_folder.mkdir(exist_ok=True)

# Crear subcarpetas
for fs in focal_spots:
    (main_folder / fs).mkdir(exist_ok=True)

print("✔ Carpetas creadas correctamente")
# Out:
# ✔ Carpetas creadas correctamente

# %%
def ImagenesR(name,Npixeles):
    I=[]
    for k in range(0,len(name),Npixeles*Npixeles):
        Im=np.zeros((Npixeles,Npixeles))
        for j in range(Npixeles):
            for i in range(Npixeles):
                Im[j,i]=name[i+Npixeles*j+k]
        I.append(Im)
    return I
def Imagenes(name,Npixeles,NI):
    D=[]
    for i in range(1,NI+1):
        Raw=np.fromfile(name+"{}.raw".format(i), dtype='float32')
        K=ImagenesR(Raw,Npixeles)
        D.append(K)
    return D
def sumar_imagenes(name1, name2, Npixeles):
    # Inicializar una matriz para almacenar la suma de las imágenes
    suma_imagenes = np.zeros((Npixeles, Npixeles), dtype='float32')
    
    # Iterar sobre las imágenes (de R00 a R09)
    for i in range(1,3):  # Cambiado a 10 para incluir R00 a R09
        # Construir el nombre del archivo
        nombre_archivo = f"{name1}{i:01d}{name2}1.raw"
        
        # Leer la imagen desde el archivo .raw
        Raw = np.fromfile(nombre_archivo, dtype='float32')
        
        # Convertir la imagen en una matriz 2D
        K = ImagenesR(Raw, Npixeles)
        
        # Sumar la imagen actual a la suma acumulada
        suma_imagenes += K[0]  # Asumiendo que K[0] es la matriz 2D de la imagen
    
    return suma_imagenes
def Imagenes2(name1, name2, Npixeles, NI):    
    D = []
    for i in range(20):
        Raw = np.fromfile(name1 + "{:02d}".format(i) + name2 + "1.raw", dtype='float32')
        K = ImagenesR(Raw, Npixeles)
        D.append(K[0])#[25:225,25:225])  # Append the first image in the list to avoid extra dimension
    return D
def ImagenesA(name,Npixeles,NI,NThr):
    A=[]
    for i in range(NThr):
        Mean=np.zeros((Npixeles, Npixeles))
        for j in range (NI):
            Mean=Mean+name[j][i]
        A.append(Mean)
    return A
def CNR(meanS,meanB,stdB):
    CNR = (meanB - meanS)/stdB
    return CNR
'''
def copiar_imagenes(base_name, start, end):
    for i in range(start, end + 1):
        new_name = base_name.replace('TiC3', f'TiC{i}')
        os.system(f'cp {base_name} {new_name}')

    # Uso de la función para copiar la imagen con los nuevos nombres
#base_name = 'TiC_PMMA_4Sands/test_PMMA4_TiC3_19kev_R09__d0.1m_a15um_p62um_step-4.2_dith23.25_1.raw'
#copiar_imagenes(base_name, 3, 10)
'''
RAW = Imagenes2(nameRAW1,nameRAW2,Npixeles,NI)
#RAW2 = Imagenes2(nameRAW1,nameRAW3,Npixeles,NI)
REF = Imagenes2(nameRAW4,nameRAW2,Npixeles,NI)
REF = np.array(REF)
RAW = np.array(RAW)

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.imshow(REF[1]
           ,cmap='gray')
#plt.colorbar()
plt.axis('off')
'''
plt.subplot(2,2,2)
plt.imshow(REF[0],cmap='bone')
plt.colorbar()
plt.subplot(2,2,3)
plt.imshow(RAW[17]/REF[17],cmap='bone')
plt.colorbar()
print(RAW.shape,REF.shape)
plt.subplot(2,2,4)
plt.plot(np.mean((RAW[0]/REF[0]),axis=0), label='Profile mean')
'''
print(RAW.shape)
np.savetxt(f'Mono_sphere_28kev/Sample.txt', RAW[0], fmt='%f')
# Out:
# (20, 256, 256)

# %%
plt.hist(np.ravel(RAW[0]),bins=50,color="blue",label="100um")
#plt.hist(np.ravel(RAW2[1]),bins=50,color="red",alpha=0.5,label="10um")
plt.legend()

# %%
print(np.min(RAW[0]))
# Out:
# 0.0

# %%
plt.figure(figsize=(10,10))
for i in range(20):
    plt.subplot(5,4,i+1)
    plt.imshow(RAW[i]/REF[i],cmap='bone')
    plt.title(f'Energy_{i:02d}')
# Out:
# /tmp/ipykernel_2706204/3986161698.py:4: RuntimeWarning: divide by zero encountered in divide
#   plt.imshow(RAW[i]/REF[i],cmap='bone')
# /tmp/ipykernel_2706204/3986161698.py:4: RuntimeWarning: invalid value encountered in divide
#   plt.imshow(RAW[i]/REF[i],cmap='bone')

# %%
#RAW = RAW[1:]
#REF = REF[1:]

# %%
Vis = []

for k in range(18):
    V_local = []
    for x in range(0, 200, 50):
        for y in range(0, 200, 50):
            region = RAW[k][x:x+50, y:y+50]
            mean_region = np.mean(region)
            rms_region = np.std(region)
            V_local.append(rms_region / mean_region)
    # promedio de todas las subventanas → visibilidad de la imagen
    Vis.append(np.mean(V_local))
Vis
# Out:
# [0.26533105660867085,
#  0.26548176535174234,
#  0.2659813171558702,
#  0.2658332230219617,
#  0.2664827316134556,
#  0.26599194020087286,
#  0.2650450381377689,
#  0.26612603821685654,
#  0.2656616096641191,
#  0.26706088846838516,
#  0.2671549066201576,
#  0.26592991080201933,
#  0.2662207492740699,
#  0.26593299677634286,
#  0.2661710800121838,
#  0.2659836010054626,
#  0.2660536574142063,
#  0.26560532041951]

# %%
import UMPA
I_ref,Isamp = [],[]
FS_Size = 300
ref = REF# Establishing empty arrays to put SB-PCXI data into
sam = RAW#np.load(f"DATA_Prosesada_14.75keV/RAW_FF_14.75keV.npy")


UMPA_res2 = UMPA.match(sam, ref, 1,max_shift=1) # provide sample and reference images in input to #UMPA, 3 is the window size (user defined)
UMPA_bias2 = UMPA.match(ref, ref, 1,max_shift=1) # UMPA sometimes can output images with a #sistematic bias: you can compute this by taking UMPA result from ref Vs ref
#UMPA_res2 = UMPA.match(np.expand_dims(sam[0],axis=0), np.expand_dims(ref[0],axis=0), 4,max_shift=10) # provide sample and reference images in input to #UMPA, 3 is the window size (user defined)
#UMPA_bias2 = UMPA.match(np.expand_dims(ref[0],axis=0), np.expand_dims(ref[0],axis=0), 4,max_shift=10) 
def inverse_grad(grad_x: np.ndarray, grad_y: np.ndarray, epsilon: float = 1e-6) -> np.ndarray:
    """
    Reconstruye la fase (phi_UMPA) a partir de los gradientes (grad_x, grad_y).
    Basado en la ecuación de Poisson: ∇²ϕ = ∇·G, donde G = (grad_x, grad_y).
    """
    rows, cols = grad_x.shape
    ky, kx = np.mgrid[-rows//2:rows//2, -cols//2:cols//2]
    kx = (2 * np.pi * kx) / cols
    ky = (2 * np.pi * ky) / rows

    # Divergencia del campo de gradientes (∇·G)
    div_G = np.fft.fft2(grad_x) * 1j * kx + np.fft.fft2(grad_y) * 1j * ky

    # Resuelve la ecuación de Poisson en espacio Fourier (evita división por cero)
    kernel = kx**2 + ky**2 + epsilon
    kernel[kernel == 0] = epsilon  # Regularización
    phi_fft = div_G / kernel

    # Transformada inversa para obtener la fase reconstruida
    phi_UMPA = np.fft.ifft2(phi_fft).real
    return phi_UMPA 
phi = inverse_grad(UMPA_res2['dx'], UMPA_res2['dy'],epsilon=1e-4)
print(phi.shape)
#guardar imagenes en formato .txt
dx = UMPA_res2['dx']-UMPA_bias2['dx']
np.savetxt(f'FS_Measurements_txt_Files/dx_SiC_60um_FS{FS_Size}um_21kev_2x150_75_AIR.txt', dx, fmt='%f')
dy = UMPA_res2['dy']-UMPA_bias2['dy']
np.savetxt(f'FS_Measurements_txt_Files/dy_SiC_60um_FS{FS_Size}um_21kev_2x150_75_AIR.txt', dy, fmt='%f')
df = UMPA_res2['df']-UMPA_bias2['df']
T = UMPA_res2['T']
np.savetxt(f'FS_Measurements_txt_Files/T_SiC_60um_FS{FS_Size}um_21kev_2x150_75_AIR.txt', T, fmt='%f')
from scipy.ndimage import gaussian_filter
dx = gaussian_filter(dx, sigma=0)  # Aplicar filtro gaussiano para suavizar
dy = gaussian_filter(dy, sigma=0)  # Aplicar filtro gaussiano

#np.savetxt("Golden_Results/dx_TiC_90um_19k_PMMA.txt", dx)
#np.savetxt("Golden_Results/dy_TiC_90um_19k_PMMA.txt", dy)
vmin = -0.15
vmax = 0.15
plt.figure(figsize=(15,15))
plt.title('UMPA results at 19kev and 1e9 events')
plt.subplot(4,4,1)
plt.imshow(-dx,cmap='gray',vmin=vmin,vmax=vmax) #here subtract bias to the result -UMPA_bias['dx']
#np.savetxt('dx_4_90.txt', UMPA_res['dx']-UMPA_bias['dx'])
plt.title('dx')
plt.colorbar()
plt.subplot(4,4,2)
plt.imshow(-dy,cmap='gray',vmin=vmin,vmax=vmax) #-UMPA_bias['dy']
plt.title('dy')
#np.savetxt('dy_4_90.txt', UMPA_res['dy']-UMPA_bias['dy'])
plt.colorbar()
plt.subplot(4,4,3)
plt.imshow(df,cmap='gray') #-UMPA_bias['T']
plt.title('df')  
plt.colorbar()
plt.subplot(4,4,4)
plt.imshow(T,cmap='gray') #-UMPA_bias['T']
plt.title('T')  
plt.colorbar()
# Out:
# Using 16 threads
# Using 16 threads
# (246, 246)
# /tmp/ipykernel_2706204/2129616011.py:53: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(4,4,1)

# %%
import glob
import os
import matplotlib.pyplot as plt
import numpy as np
from scipy.ndimage import median_filter  # Reemplaza la sintaxis vieja de scipy
from skimage import io

# ==============================================================================
# 1. FUNCIÓN LCS AISLADA Y OPTIMIZADA (Sin dependencias externas de clases)
# ==============================================================================
def calcular_LCS(reference_images, sample_images, max_shift=5.0, filtro_mediana=3):
    """Calcula las imágenes de desplazamiento (Dx, Dy) y absorción usando el sistema LCS.

    Args:
        reference_images (numpy array): Stack de imágenes de referencia (N_imagenes, alto, ancho).
        sample_images (numpy array): Stack de imágenes de muestra (N_imagenes, alto, ancho).
        max_shift (float): Umbral límite para saturar desplazamientos físicos.
        filtro_mediana (int): Tamaño del kernel para el filtro de mediana (0 para desactivar).

    Returns:
        Dx, Dy, absorption (numpy arrays de tamaño [alto, ancho])
    """
    Nz, Ny, Nx = reference_images.shape
    nb_of_point = Nz

    LHS = np.ones((nb_of_point, Ny, Nx))
    RHS = np.ones((nb_of_point, 3, Ny, Nx))
    solution = np.ones((3, Ny, Nx))

    print("Preparando matrices del sistema lineal...")
    # Preparar matrices del sistema
    for i in range(nb_of_point):
        gY_IrIr, gX_IrIr = np.gradient(reference_images[i])
        RHS[i] = [sample_images[i], gY_IrIr, gX_IrIr]
        LHS[i] = reference_images[i]

    print("Resolviendo el sistema pixel por pixel por descomposición QR (esto puede tardar)...")
    # Resolver sistema para cada píxel
    for i in range(Ny):
        for j in range(Nx):
            a = RHS[:, :, i, j]
            b = LHS[:, i, j]
            Q, R = np.linalg.qr(a)  # Descomposición QR
            Qb = np.dot(Q.T, b)

            if R[2, 2] == 0 or R[1, 1] == 0 or R[0, 0] == 0:
                temp = [1, 0, 0]
            else:
                temp = np.linalg.solve(R, Qb)  # Resolver R*x = Q^T*b
            solution[:, i, j] = temp

    absorption = 1 / solution[0]
    Dy = solution[1]
    Dx = solution[2]

    # Post-procesamiento básico: Limitar desplazamientos a un umbral (Saturación)
    Dx[Dx < -max_shift] = -max_shift
    Dx[Dx > max_shift] = max_shift
    Dy[Dy < -max_shift] = -max_shift
    Dy[Dy > max_shift] = max_shift

    # Aplicar Filtro de Mediana si se solicita
    if filtro_mediana != 0:
        Dx = median_filter(Dx, size=filtro_mediana)
        Dy = median_filter(Dy, size=filtro_mediana)

    return Dx, Dy, absorption


RAW = np.array(RAW)   # shape -> (19, 200, 200)
REF = np.array(REF)   # shape -> (19, 200, 200)
 
print(f"RAW stack: {RAW.shape}")
print(f"REF stack: {REF.shape}")
 
# Sanity check: ambos stacks deben tener la misma forma o calcular_LCS fallará
assert RAW.shape == REF.shape, (
    f"RAW {RAW.shape} y REF {REF.shape} no coinciden en forma. "
    "Revisa que NI y el recorte [25:225,25:225] sean iguales para ambos."
)
 
# Asegurar float32 (consistente con el dtype de lectura .raw)
images_stack_samp = RAW.astype(np.float32)   # muestra
images_stack       = REF.astype(np.float32)  # referencia
 
 
# ==============================================================================
# 5. EJECUCIÓN DEL LCS
# ==============================================================================
MAX_SHIFT_PERMITIDO   = 50
TAMANO_FILTRO_MEDIANA = 0
 
dx, dy, absorption = calcular_LCS(
    reference_images=images_stack,
    sample_images=images_stack_samp,
    max_shift=MAX_SHIFT_PERMITIDO,
    filtro_mediana=TAMANO_FILTRO_MEDIANA,
)
 
 
# ==============================================================================
# 6. VISUALIZACIÓN
# ==============================================================================
print("\nGraficando mapas de salida de LCS...")
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
 
im0 = axes[0].imshow(dx, cmap="gray", vmin=-0.1,vmax=0.1)
axes[0].set_title("Desplazamiento Dx (Horizontal)")
fig.colorbar(im0, ax=axes[0])
 
im1 = axes[1].imshow(dy, cmap="gray", vmin=-0.1,vmax=0.1)
axes[1].set_title("Desplazamiento Dy (Vertical)")
fig.colorbar(im1, ax=axes[1])
 
im2 = axes[2].imshow(absorption, cmap="gray")
axes[2].set_title("Absorción Calculada")
fig.colorbar(im2, ax=axes[2])
 
for ax in axes:
    ax.axis("off")
 
plt.tight_layout()
plt.show()
# Out:
# RAW stack: (20, 256, 256)
# REF stack: (20, 256, 256)
# Preparando matrices del sistema lineal...
# Resolviendo el sistema pixel por pixel por descomposición QR (esto puede tardar)...
#
# Graficando mapas de salida de LCS...

# %%
os.makedirs(f'Mono_sphere_28kev', exist_ok=True)
if not os.path.exists(f'Mono_sphere_28kev'):
    os.makedirs(f'Mono_sphere_28kev')

# %%
np.savetxt(f'Mono_sphere_28kev/dx.txt', dx, fmt='%f')
np.savetxt(f'Mono_sphere_28kev/dy.txt', dy, fmt='%f')

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib_scalebar.scalebar import ScaleBar
from skimage.measure import shannon_entropy
from skimage import data, feature, color
from skimage.transform import hough_circle, hough_circle_peaks
from skimage.metrics import structural_similarity as ssim
from skimage.draw import circle_perimeter
import xraylib as xl
import numpy as np
from sklearn.metrics import mutual_info_score
from skimage import exposure
import scipy.constants
from scipy.ndimage import shift
import PIL

# %%
n_samples_bootstrap = 1000
num_patches = 25

# %%
def k_from_E(E):
    k =  2. * np.pi * (E * 1e3 * 1.6022e-19) / (scipy.constants.h * scipy.constants.c) # in 1/m
    return k

# %%
def create_sphere(N_pix, R, cx, cy):
                       
    #cx, cy = N_pix/2, N_pix/2               # sphere center (pixels)
    
    y, x = np.ogrid[:N_pix, :N_pix]
    r = np.hypot(x - cx, y - cy)
    
    # path length projection
    proj = np.zeros((N_pix, N_pix), float)
    inside = r <= R
    proj[inside] = 2.0 * np.sqrt(R**2 - r[inside]**2)
    
    # normalize for display
    proj /= proj.max()

    return proj

# %%
def ground_truth(cx, cy, R=38, N_pix=190):
    E = 15.0  # in keV
    k = k_from_E(E)

    mat = "C6H11NO"
    mat_density = 1.14
    n = xl.Refractive_Index(mat, E, mat_density)
    delta = 1 - n.real
    mu_mass = xl.CS_Total_CP(mat, E)
    mu_in_1_m = mu_mass*mat_density*1e2 

    t_map = create_sphere(N_pix=190, R=38, cx=cx, cy=cy)

    phase_theo = delta*k*t_map
    dy_theo, dx_theo = np.gradient(phase_theo)
    dy_theo = dy_theo/np.max(dy_theo)
    dx_theo = dx_theo/np.max(dx_theo)

    return dx_theo, dy_theo, phase_theo

# %%
def to_polar(img):
    """Convert Cartesian image to polar coordinates."""
    from skimage.transform import warp_polar
    return warp_polar(img, scaling="linear")

# %%
def detect_center(image):
    # Detect edges (Canny)
    edges = feature.canny(image, sigma=2)

    #Perform Hough Transform for circles
    radii = np.arange(30, 50, 1)  # search radii range
    hough_res = hough_circle(edges, radii)

    # Identify the most prominent circle
    accums, cx, cy, radii = hough_circle_peaks(hough_res, radii,
                                           total_num_peaks=1)
    
    return cx[0], cy[0], radii[0]

# %%
def detect_border(image_polar):
    pos_border = []
    for row in range(image_polar.shape[0]):
        row_profile = np.abs(image_polar[row, :])
        max_row_profile = np.argmax(row_profile)
        pos_border.append([row, max_row_profile])
    pos_border = np.array(pos_border)
    return pos_border

# %%
folder_names = ["Mono_sphere_28kev","Mono_Sphere_28kev_CNN"]
focal_spots = [ 5,5]  # in micrometers
input_folder = "/home/c.tibambre/FS_Study/"
dx_name = "dx.txt"
dy_name = "dy.txt"
dx_images = []
dy_images = []
dx_images_polar = []
dy_images_polar = []

for folder in folder_names:
    dx = np.loadtxt(input_folder + folder + "/" + dx_name)
    print(dx.shape)
    dy = np.loadtxt(input_folder + folder + "/" + dy_name)
    dx = dx / np.max(np.abs(dx))  # Normalize to max value
    dy = dy / np.max(np.abs(dy))  # Normalize to max value
    dx_images_polar.append(to_polar(dx))
    dy_images_polar.append(to_polar(dy))
    dx_images.append(dx)
    dy_images.append(dy)
# Out:
# (256, 256)
# (256, 256)

# %%
# Find center and radius:

img1 = dx_images[0]
cx, cy, R = detect_center(img1)

print(cx, cy, R)
# Out:
# 224 6 30

# %%
ground_truth_x = ground_truth(cx=cx, cy=cy,R=R)[0]#shift(ground_truth(cx=cx, cy=cy,R=R)[0], shift=(3, 1), mode='constant', cval=0.0)
ground_truth_y = ground_truth(cx=cx, cy=cy,R=R)[1]#shift(ground_truth(cx=cx, cy=cy,R=R)[1], shift=(3, 1), mode='constant', cval=0.0)
polar_ground_truth_x = to_polar(ground_truth_x)
polar_ground_truth_y = to_polar(ground_truth_y)

ground_truth_contour_x = detect_border(image_polar=polar_ground_truth_x)
ground_truth_contour_y = detect_border(image_polar=polar_ground_truth_y)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib_scalebar.scalebar import ScaleBar

plt.rcParams['font.family'] = 'serif'

# ---------------------------------------------------------------
# CARGA DE DATOS
# ---------------------------------------------------------------
folder_names = ["Mono_sphere_28kev", "Mono_Sphere_28kev_CNN"]
focal_spots = [5, 5]  # in micrometers
input_folder = "/home/c.tibambre/FS_Study/"
dx_name = "dx.txt"
dy_name = "dy.txt"

dx_images = []
dy_images = []
dx_images_polar = []
dy_images_polar = []

crop_size = 100  # tamaño del recorte central alrededor de la esfera (ajustable)


def center_crop(img, size):
    """Recorta una imagen cuadrada al tamaño `size` tomando el centro."""
    h, w = img.shape
    top = (h - size) // 2
    left = (w - size) // 2
    return img[top:top + size, left:left + size]


for folder in folder_names:
    dx = np.loadtxt(input_folder + folder + "/" + dx_name)
    print(dx.shape)
    dy = np.loadtxt(input_folder + folder + "/" + dy_name)

    # --- OPCIÓN A: normalización individual ---
    # Cada dx/dy se escala respecto a SU PROPIO máximo absoluto, quedando
    # en el rango [-1, 1]. Esto es lo que hace que, al graficar con
    # vmin=-1, vmax=1 fijo para todas las imágenes, dx y dy (y los
    # distintos métodos) luzcan con contraste comparable en escala de
    # grises -- a costa de perder la información de magnitud relativa
    # real entre ellos.
    dx = dx / np.max(np.abs(dx))
    dy = dy / np.max(np.abs(dy))

    is_cnn = "CNN" in folder  # la última (CNN) NO se multiplica por -1

    if not is_cnn:
        dx = dx * -1
        dy = dy * -1
    else:
        # recorte de 200x200 -> 190x190
        dx = center_crop(dx, 190)
        dy = center_crop(dy, 190)

    dx_images_polar.append(to_polar(dx))
    dy_images_polar.append(to_polar(dy))
    dx_images.append(dx)
    dy_images.append(dy)

# Ground truth también se multiplica por -1
ground_truth_x = ground_truth_x * -1
ground_truth_y = ground_truth_y * -1

# ---------------------------------------------------------------
# RECORTE CENTRAL ALREDEDOR DE LA ESFERA (para el plot, no afecta los
# arrays originales usados en otros cálculos)
# ---------------------------------------------------------------
ground_truth_x_plot = center_crop(ground_truth_x, crop_size)
ground_truth_y_plot = center_crop(ground_truth_y, crop_size)
dx_images_plot = [center_crop(img, crop_size) for img in dx_images]
dy_images_plot = [center_crop(img, crop_size) for img in dy_images]

# ---------------------------------------------------------------
# GRAFICA
# ---------------------------------------------------------------
n_cols = len(focal_spots) + 1

fig, axes = plt.subplots(
    2, n_cols,
    figsize=(7.5, 4.2),        # más angosta -> menos separación visual entre columnas
    constrained_layout=True
)

# Reduce el espacio entre subplots (constrained_layout no respeta wspace/hspace
# directamente, hay que fijarlo en el layout engine)
fig.get_layout_engine().set(w_pad=0.0, h_pad=0.0, wspace=0.0, hspace=0.03)

# --- OPCIÓN A ---
# Como cada dx/dy YA se normalizó individualmente a su propio máximo en el
# loop de carga (dx = dx / np.max(np.abs(dx))), usamos vmin/vmax = ±1 fijo
# e igual para todas las imágenes. Al estar cada una ya reescalada a su
# propio máximo, todas terminan luciendo con contraste comparable en
# escala de grises. (Si en algún momento quieres ver la diferencia real
# de magnitud entre dx, dy, Ground Truth, UMPA y CNN -- Opción B -- hay
# que quitar la normalización individual y usar un vmin/vmax fijo
# calculado sobre los datos crudos.)
vmin = -1
vmax = 1

# Nombres reales de las columnas 2 y 3 (antes ambas decían "FSZ: 5 µm")
column_titles = ["UMPA", "CNN"]

# --- TOP ROW (dx images) ---
for i in range(len(focal_spots)):
    ax_dx = axes[0, i + 1]  # shift by 1
    im_dx = ax_dx.imshow(dx_images_plot[i], cmap='gray', vmin=vmin, vmax=vmax)

    ax_dx.set_title(column_titles[i], fontsize=9)
    ax_dx.tick_params(left=False, bottom=False,
                       labelleft=False, labelbottom=False)

    for spine in ax_dx.spines.values():
        spine.set_visible(False)

# --- BOTTOM ROW (dy images) ---
for i in range(len(focal_spots)):
    ax_dy = axes[1, i + 1]  # shift by 1
    im_dy = ax_dy.imshow(dy_images_plot[i], cmap='gray', vmin=vmin, vmax=vmax)

    ax_dy.tick_params(left=False, bottom=False,
                       labelleft=False, labelbottom=False)

    for spine in ax_dy.spines.values():
        spine.set_visible(False)

# --- FIRST COLUMN (Ground Truth) ---
ax_0 = axes[0, 0]
im_0 = ax_0.imshow(ground_truth_x_plot, cmap='gray', vmin=vmin, vmax=vmax)

ax_0.set_title("Ground Truth", fontsize=9)
ax_0.set_ylabel(r'$d_{x}$', fontsize=10)

ax_0.tick_params(left=False, bottom=False,
                  labelleft=False, labelbottom=False)

for spine in ax_0.spines.values():
    spine.set_visible(False)

scalebar = ScaleBar(
    22.5, "um",
    color="black",
    location="lower left",
    box_alpha=0.6,
    scale_loc="bottom",
    width_fraction=0.03
)

ax_0.add_artist(scalebar)

# --- Línea que muestra dónde se traza el perfil horizontal (dx) ---
row_center = ground_truth_x_plot.shape[0] // 2
ax_0.axhline(row_center, color='red', linestyle='--', linewidth=1)

ax_ncols = axes[1, 0]
im_ncols = ax_ncols.imshow(ground_truth_y_plot, cmap='gray', vmin=vmin, vmax=vmax)

ax_ncols.set_ylabel(r'$d_{y}$', fontsize=10)

ax_ncols.tick_params(left=False, bottom=False,
                      labelleft=False, labelbottom=False)

for spine in ax_ncols.spines.values():
    spine.set_visible(False)

# --- Línea que muestra dónde se traza el perfil vertical (dy) ---
col_center = ground_truth_y_plot.shape[1] // 2
ax_ncols.axvline(col_center, color='red', linestyle='--', linewidth=1)

# --- SINGLE SHARED COLORBAR ---
cbar = fig.colorbar(
    im_dx,
    ax=axes,
    orientation="vertical",
    fraction=0.02,
    pad=0.02
)

cbar.set_label("Displacement", fontsize=9)

# --- SAVE ---
plt.savefig("DiffPhase_vs_FocalSpotSize.pdf",
            dpi=300,
            bbox_inches='tight')

plt.savefig("DiffPhase_vs_FocalSpotSize.png",
            dpi=300,
            bbox_inches='tight')

plt.show()
# Out:
# (256, 256)
# (256, 256)

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'serif'

# ---------------------------------------------------------------
# CONFIGURACIÓN
# ---------------------------------------------------------------
pixel_size_um = 22.5  # tamaño de pixel, igual al de la ScaleBar

crop_size = 100  # tamaño del recorte central alrededor de la esfera (ajustable)


def center_crop(img, size):
    """Recorta una imagen cuadrada al tamaño `size` tomando el centro."""
    h, w = img.shape
    top = (h - size) // 2
    left = (w - size) // 2
    return img[top:top + size, left:left + size]


# Etiquetas y colores (Ground Truth, UMPA, CNN)
labels = ["Ground Truth", "UMPA", "CNN"]
colors = ["red", "gray", "blue"]
styles = ["-", "--", "-."]


def horizontal_profile(img):
    """Perfil trazado horizontalmente: toma la fila central."""
    row = img.shape[0] // 2
    profile = img[row, :]
    x = (np.arange(img.shape[1]) - img.shape[1] / 2) * pixel_size_um
    return x, profile


def vertical_profile(img):
    """Perfil trazado verticalmente (columna central), pero se retorna
    listo para graficarse en un eje horizontal (posición en X, valor en Y)."""
    col = img.shape[1] // 2
    profile = img[:, col]
    x = (np.arange(img.shape[0]) - img.shape[0] / 2) * pixel_size_um
    return x, profile


# ---------------------------------------------------------------
# LISTAS COMPLETAS: Ground Truth + UMPA + CNN
# ---------------------------------------------------------------
# Se multiplica por -1 el ground truth (igual que en el script de las
# imágenes) para que el signo sea consistente con UMPA y CNN.
ground_truth_x_plot = ground_truth_x 
ground_truth_y_plot = ground_truth_y 

all_dx = [ground_truth_x_plot] + dx_images
all_dy = [ground_truth_y_plot] + dy_images

# Recorte central alrededor de la esfera, para no arrastrar tanta área
# de fondo en el perfil
all_dx = [center_crop(img, crop_size) for img in all_dx]
all_dy = [center_crop(img, crop_size) for img in all_dy]

# Extraemos primero todos los perfiles crudos
dx_profiles = [horizontal_profile(img) for img in all_dx]
dy_profiles = [vertical_profile(img) for img in all_dy]

# --- Normalización respecto al Ground Truth ---
# Se divide cada perfil por el valor máximo absoluto del perfil del
# ground truth (índice 0), así todos quedan en la misma escala relativa
# a la referencia en vez de normalizarse cada uno por su propio máximo.
gt_dx_max = np.max(np.abs(dx_profiles[0][1]))
gt_dy_max = np.max(np.abs(dy_profiles[0][1]))

dx_profiles = [(x, p / gt_dx_max) for x, p in dx_profiles]
dy_profiles = [(x, p / gt_dy_max) for x, p in dy_profiles]

# ---------------------------------------------------------------
# FIGURA CON 2 SUBPLOTS
# ---------------------------------------------------------------
fig, axes = plt.subplots(1, 2, figsize=(10, 4), constrained_layout=True)

ax_dx, ax_dy = axes

# --- Subplot izquierdo: perfiles de dx (trazo horizontal) ---
for i, (x, profile) in enumerate(dx_profiles):
    ax_dx.plot(x, profile, styles[i % len(styles)], color=colors[i],
               label=labels[i], lw=1.2)

ax_dx.set_title(r'Horizontal profile of $\partial_x \phi(x,y)$', fontsize=10)
ax_dx.set_xlabel("Position (µm)", fontsize=9)
ax_dx.set_ylabel("Differential phase (normalized to GT)", fontsize=9)
ax_dx.legend(fontsize=8)
ax_dx.grid(alpha=0.3)

# --- Subplot derecho: perfiles de dy (trazo vertical, graficado horizontal) ---
for i, (x, profile) in enumerate(dy_profiles):
    ax_dy.plot(x, profile, styles[i % len(styles)], color=colors[i],
               label=labels[i], lw=1.2)

ax_dy.set_title(r'Vertical profile of $\partial_y \phi(x,y)$', fontsize=10)
ax_dy.set_xlabel("Position (µm)", fontsize=9)
ax_dy.set_ylabel("Differential phase (normalized to GT)", fontsize=9)
ax_dy.legend(fontsize=8)
ax_dy.grid(alpha=0.3)

# --- SAVE ---
plt.savefig("DiffPhase_Profiles.pdf", dpi=300, bbox_inches='tight')
plt.savefig("DiffPhase_Profiles.png", dpi=300, bbox_inches='tight')

plt.show()
# Out:
# /tmp/ipykernel_2706204/3586178290.py:72: RuntimeWarning: invalid value encountered in divide
#   dx_profiles = [(x, p / gt_dx_max) for x, p in dx_profiles]
# /tmp/ipykernel_2706204/3586178290.py:72: RuntimeWarning: divide by zero encountered in divide
#   dx_profiles = [(x, p / gt_dx_max) for x, p in dx_profiles]
# /tmp/ipykernel_2706204/3586178290.py:73: RuntimeWarning: invalid value encountered in divide
#   dy_profiles = [(x, p / gt_dy_max) for x, p in dy_profiles]
# /tmp/ipykernel_2706204/3586178290.py:73: RuntimeWarning: divide by zero encountered in divide
#   dy_profiles = [(x, p / gt_dy_max) for x, p in dy_profiles]

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib_scalebar.scalebar import ScaleBar

plt.rcParams['font.family'] = 'serif'

# ---------------------------------------------------------------
# CONFIGURACIÓN GENERAL
# ---------------------------------------------------------------
pixel_size_um = 55    # Tamaño de píxel en µm
crop_size = 100       # Tamaño del recorte central alrededor de la esfera
shift_pixels = 3      # Píxeles a desplazar la CNN hacia la derecha en el perfil

input_folder = "/home/c.tibambre/FS_Study/"
folder_names = ["Mono_sphere_28kev", "Mono_Sphere_28kev_CNN"]
dx_name = "dx.txt"
dy_name = "dy.txt"

labels = ["Ground Truth", "UMPA", "CNN"]

# --- Paletas y estilos para perfiles (Columna 4) ---
dx_colors = ["black", "gray", "red"]
dx_styles = ["--", "-", "-"]

dy_colors = ["black", "gray", "dodgerblue"]
dy_styles = ["--", "-", "-"]


# ---------------------------------------------------------------
# FUNCIONES AUXILIARES
# ---------------------------------------------------------------
def center_crop(img, size):
    """Recorta una imagen cuadrada al tamaño `size` tomando el centro."""
    h, w = img.shape
    top = (h - size) // 2
    left = (w - size) // 2
    return img[top:top + size, left:left + size]


def horizontal_profile(img):
    """Perfil trazado horizontalmente: arranca en 0 µm."""
    row = img.shape[0] // 2
    profile = img[row, :]
    x = np.arange(img.shape[1]) * pixel_size_um
    return x, profile


def vertical_profile(img):
    """Perfil trazado verticalmente: arranca en 0 µm."""
    col = img.shape[1] // 2
    profile = img[:, col]
    x = np.arange(img.shape[0]) * pixel_size_um
    return x, profile


# ---------------------------------------------------------------
# CARGA Y PROCESAMIENTO DE DATOS
# ---------------------------------------------------------------
dx_images = []
dy_images = []
dx_images_polar = []
dy_images_polar = []

for folder in folder_names:
    dx = np.loadtxt(input_folder + folder + "/" + dx_name)
    dy = np.loadtxt(input_folder + folder + "/" + dy_name)

    # Normalización individual para el contraste visual de las imágenes
    dx = dx / np.max(np.abs(dx))
    dy = dy / np.max(np.abs(dy))

    is_cnn = "CNN" in folder

    if not is_cnn:
        dx = dx * -1
        dy = dy * -1
    else:
        dx = center_crop(dx, 190)
        dy = center_crop(dy, 190)

    # Asumiendo que to_polar está definido en tu entorno
    if 'to_polar' in globals():
        dx_images_polar.append(to_polar(dx))
        dy_images_polar.append(to_polar(dy))

    dx_images.append(dx)
    dy_images.append(dy)

# Ground Truth cambio de signo
ground_truth_x = ground_truth_x * -1
ground_truth_y = ground_truth_y * -1

# Listas completas ordenadas: [Ground Truth, UMPA, CNN]
all_dx = [ground_truth_x] + dx_images
all_dy = [ground_truth_y] + dy_images

# Recorte central para visualización y perfiles
all_dx_plot = [center_crop(img, crop_size) for img in all_dx]
all_dy_plot = [center_crop(img, crop_size) for img in all_dy]


# ---------------------------------------------------------------
# EXTRACCIÓN Y NORMALIZACIÓN DE PERFILES (COLUMNA 4)
# ---------------------------------------------------------------
dx_profiles = [horizontal_profile(img) for img in all_dx_plot]
dy_profiles = [vertical_profile(img) for img in all_dy_plot]

# Normalización respecto al Ground Truth (índice 0)
gt_dx_max = np.max(np.abs(dx_profiles[0][1]))
gt_dy_max = np.max(np.abs(dy_profiles[0][1]))

dx_profiles = [(x, p / gt_dx_max) for x, p in dx_profiles]
dy_profiles = [(x, p / gt_dy_max) for x, p in dy_profiles]

# Desplazamiento manual en X para la CNN (índice 2)
x_dx_cnn, p_dx_cnn = dx_profiles[2]
dx_profiles[2] = (x_dx_cnn + (shift_pixels * pixel_size_um), p_dx_cnn)

x_dy_cnn, p_dy_cnn = dy_profiles[2]
dy_profiles[2] = (x_dy_cnn + (shift_pixels * pixel_size_um), p_dy_cnn)


# ---------------------------------------------------------------
# CONSTRUCCIÓN DE LA FIGURA (2 FILAS x 4 COLUMNAS)
# ---------------------------------------------------------------
fig, axes = plt.subplots(2, 4, figsize=(11, 5.5), constrained_layout=True)

# Ajuste fino entre subplots
fig.get_layout_engine().set(w_pad=0.02, h_pad=0.02, wspace=0.05, hspace=0.05)

vmin, vmax = -1, 1

# --- COLUMNAS 0, 1, 2: IMÁGENES (Ground Truth, UMPA, CNN) ---
for col_idx in range(3):
    # Fila superior (dx)
    ax_dx = axes[0, col_idx]
    im_dx = ax_dx.imshow(all_dx_plot[col_idx], cmap='gray', vmin=vmin, vmax=vmax)
    ax_dx.set_title(labels[col_idx], fontsize=9)
    ax_dx.tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)
    for spine in ax_dx.spines.values():
        spine.set_visible(False)

    # Fila inferior (dy)
    ax_dy = axes[1, col_idx]
    im_dy = ax_dy.imshow(all_dy_plot[col_idx], cmap='gray', vmin=vmin, vmax=vmax)
    ax_dy.tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)
    for spine in ax_dy.spines.values():
        spine.set_visible(False)

# Etiquetas laterales en la primera columna
axes[0, 0].set_ylabel(r'$d_{x}$', fontsize=10)
axes[1, 0].set_ylabel(r'$d_{y}$', fontsize=10)

# Escala en la imagen de Ground Truth (Fila 0, Columna 0)
scalebar = ScaleBar(
    pixel_size_um, "um",
    color="black",
    location="lower left",
    box_alpha=0.6,
    scale_loc="bottom",
    width_fraction=0.03
)
axes[0, 0].add_artist(scalebar)

# Líneas guía de corte del perfil en Ground Truth
row_center = all_dx_plot[0].shape[0] // 2
col_center = all_dy_plot[0].shape[1] // 2
axes[0, 0].axhline(row_center, color='red', linestyle='--', linewidth=1)
axes[1, 0].axvline(col_center, color='red', linestyle='--', linewidth=1)

# Colorbar compartido para las imágenes (Columnas 0 a 2)
cbar = fig.colorbar(
    im_dx,
    ax=axes[:, :3],
    orientation="vertical",
    fraction=0.02,
    pad=0.02
)
cbar.set_label("Displacement", fontsize=9)


# --- COLUMNA 3: PERFILES DE LÍNEA ---
ax_prof_dx = axes[0, 3]
ax_prof_dy = axes[1, 3]

# Perfiles dx (Superior)
for i, (x, profile) in enumerate(dx_profiles):
    ax_prof_dx.plot(x, profile, dx_styles[i], color=dx_colors[i],
                    label=labels[i], lw=1.5)

ax_prof_dx.set_title(r'Profiles d$_x$', fontsize=10)
ax_prof_dx.set_xlabel("x (µm)", fontsize=9)
ax_prof_dx.legend(fontsize=7, loc='upper left')  # <--- Ubicación superior izquierda
ax_prof_dx.grid(True, alpha=0.3)
ax_prof_dx.set_box_aspect(1)

# Perfiles dy (Inferior)
for i, (x, profile) in enumerate(dy_profiles):
    ax_prof_dy.plot(x, profile, dy_styles[i], color=dy_colors[i],
                    label=labels[i], lw=1.5)

ax_prof_dy.set_title(r'Profiles d$_y$', fontsize=10)
ax_prof_dy.set_xlabel("x (µm)", fontsize=9)
ax_prof_dy.legend(fontsize=7, loc='upper left')  # <--- Ubicación superior izquierda
ax_prof_dy.grid(True, alpha=0.3)
ax_prof_dy.set_box_aspect(1)


# ---------------------------------------------------------------
# GUARDAR Y MOSTRAR
# ---------------------------------------------------------------
plt.savefig("DiffPhase_Images_and_Profiles.pdf", dpi=300, bbox_inches='tight')
plt.savefig("DiffPhase_Images_and_Profiles.png", dpi=300, bbox_inches='tight')

plt.show()
# Out:
# /tmp/ipykernel_2706204/1442593648.py:112: RuntimeWarning: invalid value encountered in divide
#   dx_profiles = [(x, p / gt_dx_max) for x, p in dx_profiles]
# /tmp/ipykernel_2706204/1442593648.py:112: RuntimeWarning: divide by zero encountered in divide
#   dx_profiles = [(x, p / gt_dx_max) for x, p in dx_profiles]
# /tmp/ipykernel_2706204/1442593648.py:113: RuntimeWarning: invalid value encountered in divide
#   dy_profiles = [(x, p / gt_dy_max) for x, p in dy_profiles]
# /tmp/ipykernel_2706204/1442593648.py:113: RuntimeWarning: divide by zero encountered in divide
#   dy_profiles = [(x, p / gt_dy_max) for x, p in dy_profiles]

# %%
def phaseint_fourier(dpc_row, dpc_col):
    """
    Implements fourier integration method for two differential quantities.

    Assumes 2 N-dimensional arrays which contain differential quantities
    in the LAST two dimensions (-2 & -1).
    Note that the input arrays are numerical derivatives (i.e., the
    difference of adjacent pixel values), not physical derivatives (d/dx).
    In other words, this function is equivalent to numerical integration,
    similar to `np.cumsum()`.

    Parameters
    ----------
    dpc_row : ndarray
        Partial derivative of image along second-to-last axis
        (i.e., axis 0 for a 2d input, "np.diff(img, 0)").
    dpc_col : ndarray
        Partial derivative of image along last axis
        (i.e., axis 1 for a 2d input, "np.diff(img, 1)").
        Must have same shape as `dpc_row`.
        
    Returns
    -------
    img : ndarray
        Integrated image, i.e., the array `img` for which
        `dpc_row = np.diff(img, 0)` and
        `dpc_col = np.diff(img, 1)` (except that the output of
        `np.diff()` is one pixel smaller than its input, whereas `img`
        has the same shape as `dpc_row` and `dpc_col`).
    """
    import numpy as np
    
    py = dpc_row
    px = dpc_col
    sh = px.shape
    sh = np.asarray(sh)
    fac = np.ones_like(sh)
    fac[-2:] = 2
    f = np.zeros(sh * fac, dtype=complex)
    f[..., :sh[-2], :sh[-1]] = -px[..., ::-1, ::-1] - 1j*py[..., ::-1, ::-1]
    f[..., :sh[-2], sh[-1]:] = -px[..., ::-1, :] + 1j*py[..., ::-1, :]
    f[..., sh[-2]:, :sh[-1]] = px[..., :, ::-1] - 1j*py[..., :, ::-1]
    f[..., sh[-2]:, sh[-1]:] = px + 1j*py
    qy = 2*np.pi*np.fft.fftfreq(f.shape[1]).reshape((1, -1)) # horizontal
    qx = 2*np.pi*np.fft.fftfreq(f.shape[0]).reshape((-1, 1)) # vertical
    qy[0,0] = qx[0,0] = 1e-6
    inv_qc = 1. / (1j*(qx + 1j*qy))
    inv_qc[..., 0, 0] = 0
    nf = np.fft.ifft2(np.fft.fft2(f) * inv_qc)

    return np.real(nf[..., sh[-2]:, sh[-1]:])

# %%
phaseint_fourier(dx, dy)
phi_UMPA = phaseint_fourier(dx, dy)
plt.imshow(phi_UMPA, cmap='gray')
plt.colorbar()
